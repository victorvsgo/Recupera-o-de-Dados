# %% [markdown]
# ### Linkedin - Empresas em que trabalham os meus contatos

# %%
#CSV_FILE = '/Users/fabiola/Desktop/PUC/extracao-dados-web-sociais/linkedin/Connections.csv'
CSV_FILE = 'Connections-Victor.csv'

# %%
from prettytable import PrettyTable
import sys
import nltk
import csv


# Handle any known abbreviations,
# strip off common suffixes, etc.

transforms = [(', Inc.', ''), (', Inc', ''), (', LLC', ''), (', LLP', '')]

csvReader = csv.DictReader(open(CSV_FILE,encoding='utf8'), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]
companies = [c['Company'].strip() for c in contacts if c['Company'].strip() != '']

for i in range(len(companies)):
    for transform in transforms:
        companies[i] = companies[i].replace(*transform)

ufu = 'Universidade Federal de Uberlândia'      
iftm = 'Instituto Federal de Educação, Ciência e Tecnologia do Triângulo Mineiro'
puc = 'Pontifícia Universidade Católica de Minas Gerais'
zup = 'Zup Innovation'
standardize = [('Federal University of Uberlandia', ufu), 
               ('UFU - Universidade Federal de Uberlândia', ufu), 
               ('Universidade Federal de Uberlândia - UFU', ufu), 
               ('IFTM - Inst. Fed. de Educação, Ciência e Tecnologia do Triângulo Mineiro', iftm),
               ('Federal University of Uberlândia',ufu),
               ('Universidade Federal de Uberlandia',ufu),
               ('Instituto Federal de Minas Gerais',iftm),
               ('Instituto Federal Minas Gerais',iftm),
               ('UFU',ufu),
               ('PUC Minas',puc),
               ('Zup It Innovation',zup),
               ('Zup - Connect & Transform',zup)
              ]
for i in range(len(companies)):
    for standard in standardize:
        companies[i] = companies[i].replace(standard[0],standard[1])

        
        
pt = PrettyTable(['Company', 'Freq'])

pt.align['Company'] = 'l'
fdist = nltk.FreqDist(companies)
[pt.add_row([company, freq]) for (company, freq) in fdist.items() if freq > 1]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)
# Out:
# +---------------------------------------------+------+
# | Company                                     | Freq |
# +---------------------------------------------+------+
# | everis                                      |  69  |
# | Kyros Tecnologia                            |  26  |
# | Zup Innovation                              |  23  |
# | Algar Telecom                               |  20  |
# | Softbox - Soluções Inteligentes em TI       |  12  |
# | ValeCard                                    |  8   |
# | Algar Tech                                  |  8   |
# | Cedro Technologies                          |  6   |
# | Neppo Tecnologia da Informação              |  5   |
# | Autônomo                                    |  5   |
# | Tribanco                                    |  4   |
# | Sankhya Gestão de Negócios                  |  4   |
# | Performis Tecnologia de Negócios            |  4   |
# | TQI Consultoria                             |  3   |
# | Martins                                     |  3   |
# | Interação Tecnologia                        |  3   |
# | Etica Soluções Integrais                    |  3   |
# | Data Modelling Consultoria Ltda.            |  3   |
# | Cargill                                     |  3   |
# | Callink Servicos de Call Center             |  3   |
# | media-core®                                 |  2   |
# | Verity TI                                   |  2   |
# | Verity Group                                |  2   |
# | TQI - Technology and Quality on Information |  2   |
# | TQI +Tecnologia +Qualidade +Inovação        |  2   |
# | TIM Brasil                                  |  2   |
# | Syngenta                                    |  2   |
# | Subway                                      |  2   |
# | Serasa Experian                             |  2   |
# | Quarto Geek                                 |  2   |
# | QAT Global                                  |  2   |
# | Prime Team Tecnologia                       |  2   |
# | Prefeitura Municipal de Uberlândia          |  2   |
# | Performe Tecnologia da Informação           |  2   |
# | Morpheus Tecnologia                         |  2   |
# | Kyros Tecnologia - Poupex/FHE               |  2   |
# | Jiva Gestão Empresarial                     |  2   |
# | Cerveja Templária                           |  2   |
# | CJ Selecta                                  |  2   |
# | CI&T                                        |  2   |
# | Banco Santander                             |  2   |
# | Autônoma                                    |  2   |
# +---------------------------------------------+------+

# %% [markdown]
# ### Linkedin - Cargos que ocupam os meus contatos

# %%
import sys
import nltk
import csv
from prettytable import PrettyTable

professor = 'Professor de Ensino Superior'
professor_basico = 'Professor'
analista_ti = 'Analista de Sistemas'
engenheiro_sw = 'Engenheiro de Software'
transforms = [
    ('Sr.', 'Senior'),
    ('Sr', 'Senior'),
    ('Jr.', 'Junior'),
    ('Jr', 'Junior'),
    ('CEO', 'Chief Executive Officer'),
    ('COO', 'Chief Operating Officer'),
    ('CTO', 'Chief Technology Officer'),
    ('CFO', 'Chief Finance Officer'),
    ('VP', 'Vice President'),
    ('Full Professor',professor),
    ('Professor Dedicação Exclusiva',professor),
    ('Professor Adjunto nível A',professor),
    ('Associate Professor',professor),
    ('Full Time Professor',professor),
    ('Professora Assistente',professor),
    ('Professor adjunto',professor),
    ('Professor do Magistério Superior',professor),
    ('Professora Adjunto',professor),
    ('Professora',professor),
    ('Adjunct Professor',professor),
    ('Professor de Ensino Superior',professor),
    ('Docente',professor_basico),
    #('Professor',professor_basico),
    ('Analista de TI',analista_ti),
    ('Systems Analyst',analista_ti),
    ('Analista de Sistemas, Especialista',analista_ti),
    ('Analista de TI - Administradora Siebel',analista_ti),
    ('Senior System Development Analyst C++',analista_ti),
    ('Analista Desenvolvedor de Sistemas',analista_ti),
    ('Analista de sistemas',analista_ti),
    ('Analista de Sistemas Especialista',analista_ti),
    ('System Analyst and Senior Full-Stack Developer',analista_ti),
    ('Analista de TI Pleno',analista_ti),
    ('Information Technology Analyst',analista_ti),
    ('Analista de sistema',analista_ti),
    ('Desenvolvedor e Analista de Sistemas',analista_ti),
    ('Analista Programador',analista_ti),
    ('Analista de Desenvolvimento de Sistemas',analista_ti),
    ('Analista de desenvolvimento de software',analista_ti),
    ('Analista de Tecnologia da Informação',analista_ti),
    ('System Analyst',analista_ti),
    ('Software Engineer',engenheiro_sw),
    ('Software Engineering',engenheiro_sw),
    ('System Software Engineer',engenheiro_sw),
    ('Software engineer',engenheiro_sw),
    ('Senior Software Engineer Team Lead',engenheiro_sw),
    ('Senior C++ Software Engineer',engenheiro_sw),
    ('Engenheiro de software',engenheiro_sw),
    ('Senior Engenheiro de Software',engenheiro_sw),
    ('System Engenheiro de Software',engenheiro_sw),
    ('Software Developer',engenheiro_sw),
    ('Desenvolvedor',engenheiro_sw),
    ('Analista Desenvolvedor',engenheiro_sw),
    ('Analista Engenheiro de Software',engenheiro_sw),
    ('Software Development Engineer',engenheiro_sw),
    ('Senior C++ Engenheiro de Software',engenheiro_sw),
    ('Engenheiro de Software na ZUP',engenheiro_sw),
    ('Staff Engenheiro de Software',engenheiro_sw)
    
    ]

csvReader = csv.DictReader(open(CSV_FILE,encoding='utf8'), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]

# Read in a list of titles and split apart
# any combined titles like "President/CEO"
# Other variations could be handled as well such
# as "President & CEO", "President and CEO", etc.

titles = []
for contact in contacts:
    titles.extend([t.strip() for t in contact['Position'].split('/')
                  if contact['Position'].strip() != ''])

# Replace common/known abbreviations

for i in range(len(titles)):
    for transform in transforms:
        titles[i] = titles[i].replace(*transform)

# Print out a table of titles sorted by frequency

pt = PrettyTable(['Position', 'Freq'])
pt.align['Position'] = 'l'
titles_fdist = nltk.FreqDist(titles)
[pt.add_row([title, freq]) for (title, freq) in titles_fdist.items() if freq > 1]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)

# Print out a table of tokens sorted by frequency

tokens = []
for title in titles:
    tokens.extend([t.strip(',') for t in title.split()])
pt = PrettyTable(['Token', 'Freq'])
pt.align['Token'] =  'l'
tokens_fdist = nltk.FreqDist(tokens)
[pt.add_row([token, freq]) for (token, freq) in tokens_fdist.items() if freq > 1
 and len(token) > 2]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)
# Out:
# +----------------------------------------+------+
# | Position                               | Freq |
# +----------------------------------------+------+
# | Analista de Sistemas                   |  40  |
# | Engenheiro de Software                 |  17  |
# | Proprietário                           |  8   |
# | Owner                                  |  6   |
# | Chief Executive Officer                |  5   |
# | Analista de Recursos Humanos           |  5   |
# | Estagiário                             |  4   |
# | Engenheiro de Software Pleno           |  4   |
# | Diretor Comercial                      |  4   |
# | Consultor BI                           |  4   |
# | Advogado                               |  4   |
# | Sócio proprietário                     |  3   |
# | Scrum Master                           |  3   |
# | Programador                            |  3   |
# | Professor                              |  3   |
# | Gerente de projetos                    |  3   |
# | Diretor                                |  3   |
# | Coordenador                            |  3   |
# | Co-Founder                             |  3   |
# | Analista de Sistemas sênior            |  3   |
# | Analista de Sistemas Sênior            |  3   |
# | Supervisora Comercial                  |  2   |
# | Supervisor técnico                     |  2   |
# | Senior Specialist                      |  2   |
# | Senior Engenheiro de Software          |  2   |
# | Scrum master                           |  2   |
# | Psicóloga Clínica                      |  2   |
# | Programmer                             |  2   |
# | Professor de Ensino Superior de Inglês |  2   |
# | Líder de testes                        |  2   |
# | Líder de equipe                        |  2   |
# | Gerente de Projetos                    |  2   |
# | Gerente comercial                      |  2   |
# | Founder                                |  2   |
# | Executivo                              |  2   |
# | Engenheiro de Software full stack      |  2   |
# | Engenheiro de Software de front-end    |  2   |
# | Engenheiro de Software .Net            |  2   |
# | Diretora Geral                         |  2   |
# | Developer                              |  2   |
# | Consultor sênior                       |  2   |
# | Co Founder                             |  2   |
# | Centers Leader Developer               |  2   |
# | Business Intelligence Developer        |  2   |
# | Business Intelligence Analyst          |  2   |
# | Analista financeiro                    |  2   |
# | Analista de processos                  |  2   |
# | Analista de desenvolvimento            |  2   |
# | Analista de Negócios                   |  2   |
# | Analista de Business Intelligence      |  2   |
# | Administrador                          |  2   |
# +----------------------------------------+------+
# +-----------------+------+
# | Token           | Freq |
# +-----------------+------+
# | Analista        | 124  |
# | Sistemas        |  56  |
# | Software        |  50  |
# | Engenheiro      |  50  |
# | Gerente         |  25  |
# | Business        |  25  |
# | Developer       |  20  |
# | Consultor       |  20  |
# | Senior          |  19  |
# | Intelligence    |  18  |
# | Diretor         |  18  |
# | Analyst         |  18  |
# | Chief           |  16  |
# | Officer         |  15  |
# | Técnico         |  13  |
# | Coordenador     |  13  |
# | Sênior          |  12  |
# | Supervisor      |  12  |
# | Pleno           |  11  |
# | Comercial       |  11  |
# | Assistente      |  11  |
# | Professor       |  10  |
# | Specialist      |  9   |
# | Proprietário    |  9   |
# | Líder           |  9   |
# | Leader          |  9   |
# | Humanos         |  9   |
# | Executive       |  9   |
# | sênior          |  8   |
# | Executivo       |  8   |
# | Director        |  8   |
# | Auxiliar        |  8   |
# | projetos        |  7   |
# | Recursos        |  7   |
# | Programador     |  7   |
# | Owner           |  7   |
# | Manager         |  7   |
# | Desenvolvimento |  7   |
# | Consultant      |  7   |
# | Billing         |  7   |
# | Arquiteto       |  7   |
# | vendas          |  6   |
# | and             |  6   |
# | Scrum           |  6   |
# | Projetos        |  6   |
# | Engineer        |  6   |
# | Consultora      |  6   |
# | técnico         |  5   |
# | testes          |  5   |
# | Vendas          |  5   |
# | Testes          |  5   |
# | Technology      |  5   |
# | Negócios        |  5   |
# | Master          |  5   |
# | Founder         |  5   |
# | Estagiário      |  5   |
# | Data            |  5   |
# | Administrador   |  5   |
# | software        |  4   |
# | proprietário    |  4   |
# | processos       |  4   |
# | negócios        |  4   |
# | Sócio           |  4   |
# | Suporte         |  4   |
# | Superior        |  4   |
# | Sales           |  4   |
# | Representante   |  4   |
# | Quality         |  4   |
# | Programmer      |  4   |
# | Marketing       |  4   |
# | Junior          |  4   |
# | Java            |  4   |
# | Informática     |  4   |
# | Financial       |  4   |
# | Especialista    |  4   |
# | Ensino          |  4   |
# | Coach           |  4   |
# | Centers         |  4   |
# | Center          |  4   |
# | Architect       |  4   |
# | Agile           |  4   |
# | Advogado        |  4   |
# | web             |  3   |
# | sistemas        |  3   |
# | programador     |  3   |
# | front-end       |  3   |
# | financeiro      |  3   |
# | equipe          |  3   |
# | comercial       |  3   |
# | administrativo  |  3   |
# | Talent          |  3   |
# | System          |  3   |
# | Stack           |  3   |
# | Researcher      |  3   |
# | Psicóloga       |  3   |
# | Product         |  3   |
# | Processos       |  3   |
# | Partner         |  3   |
# | Operações       |  3   |
# | Operating       |  3   |
# | Mobile          |  3   |
# | Information     |  3   |
# | Head            |  3   |
# | Gestão          |  3   |
# | Finance         |  3   |
# | Faturamento     |  3   |
# | Designer        |  3   |
# | Coordinator     |  3   |
# | Coordenadora    |  3   |
# | Consultoria     |  3   |
# | Co-Founder      |  3   |
# | Automação       |  3   |
# | Assistant       |  3   |
# | Analytics       |  3   |
# | Advogada        |  3   |
# | Administrativo  |  3   |
# | tecnologia      |  2   |
# | stack           |  2   |
# | rede            |  2   |
# | pleno           |  2   |
# | operações       |  2   |
# | master          |  2   |
# | informação      |  2   |
# | iOS             |  2   |
# | gráfico         |  2   |
# | gestão          |  2   |
# | full            |  2   |
# | for             |  2   |
# | especialista    |  2   |
# | eletrônica      |  2   |
# | desenvolvimento |  2   |
# | Vendedor        |  2   |
# | VENDAS          |  2   |
# | Trabalho        |  2   |
# | Telecom         |  2   |
# | Team            |  2   |
# | Talentos        |  2   |
# | Support         |  2   |
# | Supervisora     |  2   |
# | Soluções        |  2   |
# | Sistema         |  2   |
# | Service         |  2   |
# | Segurança       |  2   |
# | Projetista      |  2   |
# | Produção        |  2   |
# | PHP             |  2   |
# | Operations      |  2   |
# | Operacional     |  2   |
# | Manutenção      |  2   |
# | Logística       |  2   |
# | Lead            |  2   |
# | Investimentos   |  2   |
# | Inglês          |  2   |
# | III             |  2   |
# | Gestor          |  2   |
# | Geral           |  2   |
# | Fundador        |  2   |
# | Functional      |  2   |
# | Full            |  2   |
# | Financeiro      |  2   |
# | Encarregado     |  2   |
# | Eletricista     |  2   |
# | Diretora        |  2   |
# | Delivery        |  2   |
# | Contas          |  2   |
# | Comunicação     |  2   |
# | Cobol           |  2   |
# | Clínica         |  2   |
# | Chefe           |  2   |
# | Brazil          |  2   |
# | Assurance       |  2   |
# | Assessor        |  2   |
# | Arquiteta       |  2   |
# | Analist         |  2   |
# | Agente          |  2   |
# | Administrative  |  2   |
# | Acquisition     |  2   |
# | .Net            |  2   |
# | .NET            |  2   |
# +-----------------+------+

# %% [markdown]
# ### Linkedin - Clusterizando meus contatos por cargos

# %%
# -*- coding: utf-8 -*-

import sys
import csv
from nltk.metrics.distance import masi_distance
from nltk.metrics.distance import jaccard_distance


DISTANCE_THRESHOLD = 0.67
DISTANCE = jaccard_distance

#DISTANCE_THRESHOLD = 0.2
#DISTANCE = masi_distance


def cluster_contacts_by_title(csv_file):
   

    #separators = ['/', 'and', '&', 'de', '-', 'e', ' ']
    separators = ['/', 'and', '&', '-', 'de']

    csvReader = csv.DictReader(open(csv_file,encoding='utf8'), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    # Normalize and/or replace known abbreviations
    # and build up list of common titles

    all_titles = []
    for i in range(len(contacts)):
        if contacts[i]['Position'] == '':
            contacts[i]['Position'] = ['']
            continue
        titles = [contacts[i]['Position']]
        for title in titles:
            for seperator in separators:
                if title.find(seperator) >= 0:
                    if title in titles:
                        titles.remove(title)
                    titles.extend([title.strip() for title in title.split(seperator)
                                   if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Position'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))

    clusters = {}
    for title1 in all_titles:
        clusters[title1] = []
        for title2 in all_titles:
            if title2 in clusters[title1] or title2 in clusters and title1 \
                in clusters[title2]:
                continue
            distance = DISTANCE(set(title1.split()), set(title2.split()))
            ##print(distance, set(title1.split()), set(title2.split()))
            if distance < DISTANCE_THRESHOLD:
                clusters[title1].append(title2)


    clusters = [clusters[title] for title in clusters if len(clusters[title]) > 1]
    
    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Position']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s.'
                                                              % (contact['First Name'], contact['Last Name'][0]))

    return clustered_contacts


if __name__ == '__main__':
    clustered_contacts = cluster_contacts_by_title(CSV_FILE)

    for titles in clustered_contacts:
        common_titles_heading = 'Common Positions: ' + ', '.join(titles)
        
        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        descriptive_terms_heading = 'Descriptive Terms: ' \
                                    + ', '.join(descriptive_terms)
        print(descriptive_terms_heading)
        print('-' * max(len(descriptive_terms_heading), len(common_titles_heading)))
        print('\n'.join(clustered_contacts[titles]))
        print()
# Out:
# Descriptive Terms: Intelligence, Business
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcus Vinícius M.
# Marcus Vinícius M.
# Franklin O.
# Alinson C.
# Warla  L.
# Ewerton L.
# Brenner M.
# Hugo A.
# Carlos Humberto N.
# Karina T.
# Otávio F.
# Samuel R.
# Rodrigo Moraes P.
# Thiago A.
# Ariel Leon L.
# Laureano F.
# Laureano F.
# Helton J.
# Letícia M.
# Felipe M.
#
# Descriptive Terms:
# --------------------------------------------------------
# Fernando M.
# Julio Anor E.
# Miranda R.
# Miranda R.
# Miranda R.
# Adilson  D.
# Flammarion C.
# Alex Sandro B.
# FELIX J.
# Maria aparecida A.
#
# Descriptive Terms: de, Ensino, Superior, Professor
# --------------------------------------------------------------------------------------------
# Ana Carla M.
# Lais F.
# Sonia G.
# Vitória R. L.
#
# Descriptive Terms:
# --------------------------------------------------------
# Mauricio de A.
# Heitor R.
# Roney R.
# Assis M.
# Jayr M.
# Adelso T.
# Raquel M.
# Terry  H.
#
# Descriptive Terms: Analista
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Daniele Cristina O.
# Thiago Willian A.
# Jardel B.
# Márcia Cristina V.
# Rodrigo F.
# Fabiano D.
# João C.
# Lorena M.
# Leonardo P.
# Marcela B.
# Raphael I.
# Norio M.
# Daniel C.
# Daniela B.
# Warla  L.
# José Eustáquio M.
# Andre O.
# Rodrigo Humberto P.
# Alison Demori B.
# Landi A.
# Paulo Henrique R.
# Wesley S.
# Luciana M.
# Leandro M.
# Vivaldo R.
# Ana Elizabeth M.
# Thais R.
# Rafael B.
# Luciene F.
# Leonildes P.
# Wellington J.
# Fernando V.
# Leo R.
# Matheus L.
# Arthur D.
# Marcelo T.
# Vagner A.
# Andreia V.
# Hellen C.
# Daniel B.
# Juliana F.
# Rondinele S.
# Fabio Sadol d.
# Jair Antonio C.
# Andrea Geralda Rosa R.
# Diego M.
# Rodrigo J.
# Rodrigo J.
# Katânia N.
# Alexandre J.
# Cleide S.
# Dyonatan Diogo Dias S.
# Érika S.
# Junior S.
# Maria Dantas d.
# Juliano P.
# Helbia d.
# Vítor B.
# MARCELO C.
# Rafaella F.
# Rafaella F.
# wilker f.
# Otávio F.
# Igor T.
# Marlem B.
# Thiago N.
# João Paulo M.
# Marcos M.
# Jerveson L.
# Samuel R.
# Pedro de Freitas S.
# Sarah A.
# Jhony M.
# João M.
# Fernando Henrique d.
# Rafael R.
# Levite D.
# Bruno A.
# Lorena C.
# Thiago H.
# Julian D.
# Mariana M.
# Bruna F.
# Lucas V.
# Jonnathan R.
# Arthur Kenji I.
# Laureano F.
# Rafael M.
# Antônio Carlos D.
# Tulio R.
# LUCAS MARIANO P.
# Gabriel D.
# Jordi R.
# Bruno C.
# Vanessa R.
# Warlley Gonçalves d.
# Leticia Fernanda B.
# Arthur M.
# Silas M.
# Osvaldo A.
# Letícia M.
# Thays L.
# Rubens L.
# Augusto G.
# Renato  V.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Augusto N.
# Bruno B.
# Guilherme S.
# Rafael F.
# Samuel L.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Patrick Godinho O.
# Rafael R.
# Bruno C.
# Gilberto M.
# Fernando Q.
# Everton A.
# Ramos J.
# Sergio S.
# Danniel F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Willian A.
# Paula B.
# Lucas T.
# Ricardo D.
# Rafael F.
# João Vitor A.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Michel Oliveira ,.
# Paulo A. S.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Igor T.
# Rafael A.
# José J.
# Henrique M.
# Hildeu N.
# Tiago S.
# Jacqueline M.
# Lucas César N.
# Vinícius R.
# João Augusto M.
# César F.
#
# Descriptive Terms: em, Técnico, eletrônica
# --------------------------------------------------------------------------------
# João Alair C.
# Júlio César Pereira d.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------
# Bruno M.
# Luisa L.
# Andre O.
# Alison Demori B.
# Arthur D.
# Aryel C.
# wilker f.
# Pedro de Freitas S.
# Elio D.
# Arthur M.
#
# Descriptive Terms: Analyst
# ------------------------------------------------------
# Brenner M.
# Jessiane G.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bharath U.
# Natália F.
# Vinícius D.
# Brenner M.
# Stephanny A.
# Rafael Maia D.
# Rafael Maia D.
# Breno S.
# Carlos F.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Grispe J.
# Bruno M.
# César B.
# Daniel C.
# Alessandra d.
# Erasmo A.
# Viviane N.
# Fabricio Ribeiro P.
# Sidney S.
# Fabíola B.
# Flávia M.
# Renato M.
# Henrique C.
# Ana Elizabeth M.
# Fernanda R.
# Gregonio E.
# Michele O.
# Gabriel P.
# Antonio Cristiano D.
# Fellipe P.
# Kriscia M.
# Ranier B.
# Douglas Alves C.
# Lilian S.
# Gildean C.
# Luciano Martins T.
# Fidelidade V.
# Thiago Henrique M.
# Washington Luiz S.
# Gabriella d.
# Neto C.
# Maria Cecília A.
# Anderson L.
#
# Descriptive Terms: Programmer
# ------------------------------------------------------------------
# Vinícius D.
# Rodrigo Morais R.
# Thalison C.
# Raissa O.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------------------------------------
# Robson X.
# César B.
# Viviane N.
# Fabricio Ribeiro P.
# Carlos Á.
# Kátia L.
# Genivaldo O.
# Daniel R.
# Joao Ricardo V.
# Luiz Henrique B.
# Vicente N.
# Douglas Alves C.
# Dionata T.
# Luciano Martins T.
# Fidelidade V.
# Jair F.
# Pro D.
# Jonatas R.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------
# Francisco D.
# Rita de Cássia C.
# Ricardo P.
# Dermeval N.
# Nilson B.
# Lucas L.
# Lilian Christina O.
#
# Descriptive Terms: Analyst
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Guilermo P.
# Sara Áquila M.
# Natália F.
# Alinson C.
# Vinícius D.
# Brenner M.
# Stephanny A.
# Joel S.
# Breno S.
# Hugo C.
# Anderson A.
# Carlos F.
# Matheus S.
# Rodrigo Moraes P.
#
# Descriptive Terms: Diretor, Executivo
# -----------------------------------------------------------------
# Robson X.
# Sidney F.
#
# Descriptive Terms:
# ------------------------------------------------
# Fabio B.
# Thiago Henrique C.
# Rodrigo J.
# Jonnathan R.
# Jonnathan R.
#
# Descriptive Terms: Quality
# ---------------------------------------------------------------------------------------------------------
# Sara Áquila M.
# Patrícia M.
# Wesley A.
#
# Descriptive Terms: de, Engenheiro
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Guilherme S.
# Rafael F.
# Samuel L.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Patrick Godinho O.
# Rafael R.
# Bruno C.
# Gilberto M.
# Everton A.
# Ramos J.
# Sergio S.
# Danniel F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Willian A.
# Paula B.
# Lucas T.
# Ricardo D.
# Rafael F.
# João Vitor A.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Paulo A. S.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Igor T.
# Rafael A.
# José J.
# Henrique M.
# Hildeu N.
# Tiago S.
# Jacqueline M.
# Lucas César N.
# Vinícius R.
# João Augusto M.
# César F.
#
# Descriptive Terms: Researcher
# -----------------------------------------------------------------------------
# Cláudio Henrique M.
# Priscila F.
# Isabella F.
#
# Descriptive Terms: da, tecnologia, informação
# ------------------------------------------------------------------------------------
# Rodrigo M.
# Ferdinando K.
#
# Descriptive Terms: de, Software, Engenheiro
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Guilherme S.
# Rafael F.
# Samuel L.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Patrick Godinho O.
# Rafael R.
# Bruno C.
# Gilberto M.
# Everton A.
# Ramos J.
# Sergio S.
# Danniel F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Willian A.
# Paula B.
# Lucas T.
# Ricardo D.
# Rafael F.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Igor T.
# Rafael A.
# José J.
# Henrique M.
# Hildeu N.
# Tiago S.
# Lucas César N.
# Vinícius R.
# João Augusto M.
# César F.
#
# Descriptive Terms: RH
# -----------------------------------
# Kyros Tecnologia - R.
# Joyce M.
# Nayane R.
# Pâmella R.
# Fabio P.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcos L.
# Marcus Vinícius M.
# Marcus Vinícius M.
# Franklin O.
# Alinson C.
# Warla  L.
# Ewerton L.
# Hugo A.
# Carlos Humberto N.
# Vinicius A.
# Karina T.
# Otávio F.
# Samuel R.
# Rodrigo Moraes P.
# Thiago A.
# Ariel Leon L.
# Laureano F.
# Laureano F.
# Helton J.
# Jessiane G.
# Letícia M.
# Felipe M.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Fabio B.
# Gabriel D.
# Thiago Willian A.
# Leandro S.
# Fábio Augusto F.
# Eric R.
# Henrique C.
# Paulo Eustáquio C.
# Renato F.
# Rafael B.
# Roberto S.
# Luis J.
# Ítalo N.
# Conrado F.
# Luis H.
# Andressa S.
# Marcelo M.
# Nayara D.
# Francisco Danilo S.
# Flammarion C.
# Vicente R.
# Osvaldo A.
#
# Descriptive Terms: Talent
# -----------------------------------------------------------------------------------
# Misia Christlieb M.
# Mohammed G.
# Isabella F.
#
# Descriptive Terms:
# -----------------------------------
# Rafael G.
# José Henrique B.
# Luis Manuel S.
# Luis Manuel S.
# Vazhakodan G.
# Daniela B.
# Daniela B.
# Douglas F.
# Alisson Felipe F.
# Kairon F.
# Kairon F.
# Bruno O.
#
# Descriptive Terms: Specialist
# -------------------------------------------------------------------------------------------------------------------
# Thiago Henrique C.
# Lucas R.
# Ricardo P.
# Manoel M.
# Wannisson F.
# Bárbara S.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------
# Fábio Augusto F.
# Leonardo P.
# Wesley S.
# Paulo Eustáquio C.
# Thais R.
# Leonildes P.
# Fernando V.
# Leo R.
# Matheus L.
# Luzidalva L.
# Adauto A.
# Marlem B.
# João M.
# Rafael R.
# Lucas V.
# Rodrigo W.
# Warlley Gonçalves d.
# Rubens L.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------
# Marcos Eduardo Q.
# Marcus Vinícius M.
# Michael H.
# Michel Oliveira ,.
#
# Descriptive Terms: Analista
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Daniele Cristina O.
# Thiago Willian A.
# Jardel B.
# Márcia Cristina V.
# Rodrigo F.
# Fabiano D.
# João C.
# Lorena M.
# Leonardo P.
# Marcela B.
# Raphael I.
# Norio M.
# Daniel C.
# Daniela B.
# Warla  L.
# José Eustáquio M.
# Andre O.
# Rodrigo Humberto P.
# Alison Demori B.
# Landi A.
# Paulo Henrique R.
# Wesley S.
# Luciana M.
# Leandro M.
# Vivaldo R.
# Ana Elizabeth M.
# Thais R.
# Rafael B.
# Luciene F.
# Leonildes P.
# Wellington J.
# Fernando V.
# Leo R.
# Matheus L.
# Arthur D.
# Marcelo T.
# Vagner A.
# Andreia V.
# Hellen C.
# Daniel B.
# Juliana F.
# Rondinele S.
# Fabio Sadol d.
# Jair Antonio C.
# Andrea Geralda Rosa R.
# Diego M.
# Rodrigo J.
# Rodrigo J.
# Katânia N.
# Alexandre J.
# Cleide S.
# Dyonatan Diogo Dias S.
# Érika S.
# Junior S.
# Maria Dantas d.
# Juliano P.
# Helbia d.
# Vítor B.
# MARCELO C.
# Rafaella F.
# wilker f.
# Otávio F.
# Igor T.
# Marlem B.
# Thiago N.
# João Paulo M.
# Marcos M.
# Jerveson L.
# Samuel R.
# Pedro de Freitas S.
# Sarah A.
# Jhony M.
# João M.
# Fernando Henrique d.
# Rafael R.
# Levite D.
# Bruno A.
# Lorena C.
# Thiago H.
# Julian D.
# Mariana M.
# Bruna F.
# Lucas V.
# Jonnathan R.
# Arthur Kenji I.
# Laureano F.
# Rafael M.
# Antônio Carlos D.
# Tulio R.
# LUCAS MARIANO P.
# Gabriel D.
# Jordi R.
# Bruno C.
# Vanessa R.
# Warlley Gonçalves d.
# Leticia Fernanda B.
# Arthur M.
# Silas M.
# Osvaldo A.
# Letícia M.
# Thays L.
# Rubens L.
# Augusto G.
# Renato  V.
#
# Descriptive Terms: nadora
# -----------------------------------------
# Lara L.
# Rose O.
#  Hingrid Therèse R.
#
# Descriptive Terms: s
# ------------------------------------------
# Gesmar d.
# Wagner F.
#
# Descriptive Terms: Vendas
# -------------------------------------------------------
# Renato M.
# Fabrício N.
# Arthur Fernandes de S.
# Richard R.
#  Hingrid Therèse R.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcus Vinícius M.
# Marcus Vinícius M.
# Franklin O.
# Alinson C.
# Warla  L.
# Ewerton L.
# Hugo A.
# Carlos Humberto N.
# Vanessa M.
# Karina T.
# Otávio F.
# Samuel R.
# Rodrigo Moraes P.
# Thiago A.
# Ariel Leon L.
# Gabriel Hernandez S.
# Khalid Abdullah A.
# Laureano F.
# Laureano F.
# Jessiane G.
# Letícia M.
#
# Descriptive Terms: e
# -------------------------------------------
# Lariane d.
# Neto C.
#
# Descriptive Terms: técnico
# ----------------------------------------------------------------
# Herivelton M.
# Silvio Carlos d.
# Márcio A.
# Marcos M.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------
# Henrique C.
# Henrique C.
# Davi C.
# Neto C.
#
# Descriptive Terms:
# --------------------------------------------------------------------
# Daniel R.
# Francisco D.
# Kamila B.
# Anderson B.
# Gee M.
# Neto C.
#
# Descriptive Terms: r
# -------------------------------------------------------------------------------------------
# Antônio C.
# Rafael G.
# Fabiano F.
# Wesley P.
# Francisco D.
# Francisco D.
# Luis Manuel S.
# Luis Manuel S.
# Danilo H.
# Vazhakodan G.
# Rita de Cássia C.
# Daniela B.
# Daniela B.
# Graciele d.
# Ricardo P.
# José Pedro D.
# Douglas F.
# Alisson Felipe F.
# Herivelton M.
# Lorena B.
# Kairon F.
# Kairon F.
# Nilson B.
# Lucas L.
# Gustavo F.
# Bruno O.
# Bruno O.
# Pablo P.
# Diego V.
# Thiego R.
# Ronaldo P.
# Tiago R.
#
# Descriptive Terms: Junior
# ------------------------------------------------------------------------
# Hellen C.
# Dyonatan Diogo Dias S.
# Bruna F.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------
# Edson Antonio De L.
# Bruno M.
# Gustavo B.
# Jennifer d.
# JEAN T.
# Leandro Cassilha K.
# Raul A.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------
# JEAN T.
# Lara L.
# Andreia V.
# Juliana F.
# Jair Antonio C.
# Eliane C.
# Lorena C.
# Mariana M.
#
# Descriptive Terms: nador
# -----------------------------------------------
# Daniel R.
# Fábio C.
# Daniel R.
# Anderson R.
# .Emanuel P.
# Luiz Natal S.
# Vanderlei G.
# Bruno R.
# Fabrício N.
# Amilker C.
# Raphael M.
# Elio D.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcos Antonio O.
# Jharbas A.
# Victor A.
# Márcia Cristina V.
# Guilherme S.
# Willian B.
# Mauricio D.
# Raphael I.
# Arthur D.
# Hugo Humberto R.
# Jéssica D.
# Thiago P.
# Alexandre F.
# Vitor Bruno L.
# Thiago A.
# Jonnathan R.
# Laureano F.
# Kayke M.
#
# Descriptive Terms: Chief, Officer
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Antônio C.
# Guilherme P.
# Humberto O.
# Edjay M.
# Diego D.
# Rafael M.
# Bruno O.
# Bruno O.
# Bruno O.
# Bruno O.
# WG  L.
# Thales M.
# Fernando S.
# Fernando S.
# Gustavo S.
# Wanderson M.
#
# Descriptive Terms: Executivo
# --------------------------------------------------------------------------
# Fernando M.
# Robson X.
# Julio Anor E.
# Miranda R.
# Adilson  D.
# Antonio Carlos T.
#
# Descriptive Terms: Architect
# --------------------------------------------------------------------------------------------
# Marcos Eduardo Q.
# Marcus Vinícius M.
# Marcus Vinícius M.
#
# Descriptive Terms:
# -----------------------------------
# José Henrique B.
# Marcelo S.
# Luis Manuel S.
# Daniela B.
# Kairon F.
# Bruno O.
# Neto C.
#
# Descriptive Terms: Of
# --------------------------------------------------------------------------------------------------------------
# Flávio P.
# JEANDERNEY F.
# Antônio Augusto S.
#
# Descriptive Terms:
# ---------------------------------------------------------
# MARCELO B.
# Naize D.
# Neto C.
#
# Descriptive Terms: operações
# --------------------------------------------
# Lucas Emiliano d.
# Tatiane M.
#
# Descriptive Terms: Professor
# --------------------------------------------------
# André L.
# Rodrigo B.
# Emílio D.
# Juliano A.
# Igor M.
#
# Descriptive Terms: Developer
# ----------------------------------------------------------------------------------------------------
# Marcos L.
# Rodrigo S.
# Rodrigo S.
# Vinicius A.
# Miriene P.
# Thiago F.
#
# Descriptive Terms:
# -------------------------------------------------------------------------
# Bruno M.
# Lucas C.
# Gustavo B.
# Josenildo J.
# Leandro Cassilha K.
# Raul A.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------
# Bruno W.
# Elismar M.
# Arthur G.
# Érika S.
# Raquel A.
# Rosana S.
# Pedro H.
# Maria Cecília A.
# Wagner S.
#
# Descriptive Terms: Projetos
# -------------------------------------------
# Erasmo A.
# Gregonio E.
# Thiego R.
# Rafaella F.
# Rafaella F.
# Rose O.
# Tatiana N.
#
# Descriptive Terms: negócios
# ----------------------------------------------------
# Daniel R.
# Elisangela F.
# Julio Anor E.
# Washington Luiz S.
#
# Descriptive Terms: e
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Daniele Cristina O.
# Gabriel D.
# Leonardo Batista d.
# JEAN T.
# Gustavo F.
# Helbia d.
# Amilker C.
# Vanessa V.
# Richard R.
# Thiago Henrique M.
# Neto C.
#
# Descriptive Terms: Consultor
# -------------------------------------------------------
# Gabriel D.
# Conrado F.
# Luis H.
# Flammarion C.
# Antonio Carlos T.
#
# Descriptive Terms: Manager
# ---------------------------------------------------------------------------------
# Thiago S.
# Ary R.
# Mohammed G.
# Gustavo L.
#
# Descriptive Terms: Director
# -----------------------------------------------
# Fernando M.
# Bruno N.
#
# Descriptive Terms: Manager
# ----------------------------------------------------------------
# Ary R.
# Mohammed G.
# Gustavo L.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Márcia Cristina V.
# Danilo H.
# Rodrigo F.
# João C.
# Marcela B.
# Raphael I.
# Daniel C.
# Daniela B.
# José Eustáquio M.
# Vivaldo R.
# Luciene F.
# Rondinele S.
# Andrea Geralda Rosa R.
# Diego M.
# Junior S.
# Vítor B.
# Marcelo Gomides M.
# Jhony M.
# Levite D.
# Thiago H.
# Julian D.
# Jonnathan R.
# Silas M.
# Isadora R.
# Renato  V.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------------------
# Fabio B.
# Thiago Willian A.
# Henrique C.
# Rafael B.
# Roberto S.
# Ítalo N.
# Andressa S.
# Marcelo M.
# Nayara D.
# Nayara D.
# Natasha H.
# Francisco Danilo S.
# Vicente R.
# Osvaldo A.
#
# Descriptive Terms: Lea
# ---------------------------------------------------------------
# Francisco D.
# Francisco D.
# Ricardo P.
# Nilson B.
# Lilian Christina O.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------------------------
# Danilo H.
# Rodrigo F.
# João C.
# Rodrigo C.
# Marcela B.
# Daniel C.
# José Eustáquio M.
# Vivaldo R.
# Luciene F.
# Luzidalva L.
# Andrea Geralda Rosa R.
# Diego M.
# Vítor B.
# Marcelo Gomides M.
# Jhony M.
# Levite D.
# Thiago H.
# Julian D.
# Jonnathan R.
# Silas M.
# Renato  V.
#
# Descriptive Terms: Intelligence, Business
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcus Vinícius M.
# Marcus Vinícius M.
# Alinson C.
# Warla  L.
# Ewerton L.
# Hugo A.
# Carlos Humberto N.
# Karina T.
# Otávio F.
# Samuel R.
# Rodrigo Moraes P.
# Thiago A.
# Ariel Leon L.
# Laureano F.
# Laureano F.
# Letícia M.
#
# Descriptive Terms: Testes
# ---------------------------------------------------------------------------
# Daniela B.
# Landi A.
# Helbia d.
# Gabriel D.
# Augusto G.
#
# Descriptive Terms: Engineer
# -------------------------------------------------------------------------
# Nubio G.
# Jayr M.
# Thiago B.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Daniele Cristina O.
# César B.
# Thiago Willian A.
# Jardel B.
# Márcia Cristina V.
# Rodrigo F.
# Daniel C.
# Fabiano D.
# João C.
# Lorena M.
# Leonardo P.
# Marcela B.
# Fabricio Ribeiro P.
# Raphael I.
# Norio M.
# Daniel C.
# Daniela B.
# Warla  L.
# José Eustáquio M.
# Andre O.
# Rodrigo Humberto P.
# Alison Demori B.
# Landi A.
# Wesley S.
# Luciana M.
# Leandro M.
# Vivaldo R.
# Ana Elizabeth M.
# Thais R.
# Rafael B.
# Luciene F.
# Leonildes P.
# Fernanda R.
# Wellington J.
# Fernando V.
# Leo R.
# Matheus L.
# Arthur D.
# Marcelo T.
# Vagner A.
# Andreia V.
# Hellen C.
# Daniel B.
# Juliana F.
# Rondinele S.
# Fabio Sadol d.
# Jair Antonio C.
# Andrea Geralda Rosa R.
# Diego M.
# Rodrigo J.
# Rodrigo J.
# Katânia N.
# Alexandre J.
# Michele O.
# Cleide S.
# Dyonatan Diogo Dias S.
# Érika S.
# Junior S.
# Maria Dantas d.
# Juliano P.
# Helbia d.
# Vítor B.
# MARCELO C.
# Rafaella F.
# Douglas Alves C.
# wilker f.
# Otávio F.
# Igor T.
# Marlem B.
# Thiago N.
# João Paulo M.
# Marcos M.
# Jerveson L.
# Samuel R.
# Pedro de Freitas S.
# Sarah A.
# Jhony M.
# João M.
# Fernando Henrique d.
# Rafael R.
# Levite D.
# Bruno A.
# Gildean C.
# Lorena C.
# Thiago H.
# Julian D.
# Luciano Martins T.
# Mariana M.
# Bruna F.
# Lucas V.
# Jonnathan R.
# Arthur Kenji I.
# Laureano F.
# Rafael M.
# Antônio Carlos D.
# Tulio R.
# LUCAS MARIANO P.
# Gabriel D.
# Jordi R.
# Bruno C.
# Vanessa R.
# Warlley Gonçalves d.
# Leticia Fernanda B.
# Arthur M.
# Silas M.
# Osvaldo A.
# Letícia M.
# Thays L.
# Rubens L.
# Augusto G.
# Renato  V.
#
# Descriptive Terms: Especialist, M2M
# ---------------------------------------------------------------------------
# Guilherme P.
# Guilherme P.
#
# Descriptive Terms: Specialist
# --------------------------------------------------------------------------------------------
# Thiago Henrique C.
# Lucas R.
# Ricardo P.
# Manoel M.
# Wannisson F.
#
# Descriptive Terms: Geral, Diretora
# -------------------------------------------------
# Ana O.
# Thais C.
#
# Descriptive Terms: de, Software, Engenheiro
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Guilherme S.
# Rafael F.
# Samuel L.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Patrick Godinho O.
# Rafael R.
# Bruno C.
# Gilberto M.
# Everton A.
# Sergio S.
# Danniel F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Willian A.
# Paula B.
# Lucas T.
# Ricardo D.
# Rafael F.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Igor T.
# Rafael A.
# José J.
# Henrique M.
# Hildeu N.
# Tiago S.
# Lucas César N.
# Vinícius R.
# João Augusto M.
# César F.
#
# Descriptive Terms: Engineer
# -------------------------------------------------------
# Nubio G.
# Jayr M.
#
# Descriptive Terms: processos, e
# --------------------------------------------------------------
# Amilker C.
# Bruno C.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Daniele Cristina O.
# Thiago Willian A.
# Jardel B.
# Márcia Cristina V.
# Rodrigo F.
# Fabiano D.
# João C.
# Lorena M.
# Leonardo P.
# Marcela B.
# Raphael I.
# Norio M.
# Daniel C.
# Daniela B.
# Warla  L.
# José Eustáquio M.
# Andre O.
# Rodrigo Humberto P.
# Alison Demori B.
# Landi A.
# Wesley S.
# Luciana M.
# Leandro M.
# Vivaldo R.
# Thais R.
# Rafael B.
# Luciene F.
# Leonildes P.
# Wellington J.
# Fernando V.
# Leo R.
# Matheus L.
# Arthur D.
# Marcelo T.
# Vagner A.
# Andreia V.
# Hellen C.
# Daniel B.
# Juliana F.
# Rondinele S.
# Fabio Sadol d.
# Fabio Sadol d.
# Jair Antonio C.
# Andrea Geralda Rosa R.
# Diego M.
# Rodrigo J.
# Rodrigo J.
# Katânia N.
# Alexandre J.
# Cleide S.
# Dyonatan Diogo Dias S.
# Érika S.
# Junior S.
# Maria Dantas d.
# Juliano P.
# Helbia d.
# Vítor B.
# MARCELO C.
# Rafaella F.
# wilker f.
# Otávio F.
# Igor T.
# Marlem B.
# Thiago N.
# João Paulo M.
# Marcos M.
# Jerveson L.
# Samuel R.
# Pedro de Freitas S.
# Sarah A.
# Jhony M.
# João M.
# Fernando Henrique d.
# Rafael R.
# Levite D.
# Bruno A.
# Lorena C.
# Thiago H.
# Julian D.
# Mariana M.
# Bruna F.
# Lucas V.
# Jonnathan R.
# Arthur Kenji I.
# Laureano F.
# Rafael M.
# Antônio Carlos D.
# Tulio R.
# LUCAS MARIANO P.
# Gabriel D.
# Jordi R.
# Bruno C.
# Vanessa R.
# Warlley Gonçalves d.
# Leticia Fernanda B.
# Arthur M.
# Silas M.
# Osvaldo A.
# Letícia M.
# Thays L.
# Rubens L.
# Augusto G.
# Renato  V.
#
# Descriptive Terms: Merch, Vendas, e
# --------------------------------------------------------------
# Richard R.
# Richard R.
#
# Descriptive Terms: de, Software, Engenheiro
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Guilherme S.
# Rafael F.
# Samuel L.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Patrick Godinho O.
# Rafael R.
# Bruno C.
# Gilberto M.
# Everton A.
# Danniel F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Willian A.
# Paula B.
# Lucas T.
# Ricardo D.
# Rafael F.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Igor T.
# Rafael A.
# José J.
# Henrique M.
# Hildeu N.
# Tiago S.
# Lucas César N.
# Vinícius R.
# João Augusto M.
# César F.
#
# Descriptive Terms: Specialist
# --------------------------------------------------------------------
# Thiago Henrique C.
# Lucas R.
# Ricardo P.
# Wannisson F.
#
# Descriptive Terms: Sênior
# --------------------------------------------------------------------------------------------------------
# Fabiano D.
# Daniela B.
# Rondinele S.
# Junior S.
# Isadora R.
#
# Descriptive Terms:
# -----------------------------------------------------------
# Wesley S.
# Thais R.
# Leonildes P.
# Fernando V.
# Matheus L.
# Adauto A.
# Marlem B.
# João M.
# Rafael R.
# Lucas V.
# Rodrigo W.
# Warlley Gonçalves d.
# Tatiane M.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Guilherme S.
# Rafael F.
# Samuel L.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Patrick Godinho O.
# Rafael R.
# Bruno C.
# Gilberto M.
# Everton A.
# Danniel F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Willian A.
# Paula B.
# Lucas T.
# Ricardo D.
# Rafael F.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Michel Oliveira ,.
# Paulo A. S.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Igor T.
# Rafael A.
# José J.
# Henrique M.
# Hildeu N.
# Tiago S.
# Jacqueline M.
# Lucas César N.
# Vinícius R.
# João Augusto M.
#
# Descriptive Terms: Developer
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcos L.
# Rodrigo S.
# Rita de Cássia C.
# Tulio d.
# Nilson B.
# Lucas L.
# Lorrayne P.
# Vinicius A.
# Bruno B.
# jheime s.
# Paulo Cesar C.
# Thiago F.
# Rodolpho A.
#
# Descriptive Terms: Gerente
# -------------------------------------------
# Grispe J.
# Alessandra d.
# Erasmo A.
# Fabíola B.
# Flávia M.
# Renato M.
# Henrique C.
# Gregonio E.
# Gabriel P.
# MARCELO C.
# Fellipe P.
# Kriscia M.
# Ranier B.
# Lilian S.
# Thiago Henrique M.
# Washington Luiz S.
# Gabriella d.
# Neto C.
# Anderson L.
#
# Descriptive Terms: Developer
# -------------------------------------------------------------------------------------------------------------------------
# Marcos L.
# Rita de Cássia C.
# Tulio d.
# Nilson B.
# Lucas L.
# Lorrayne P.
# Vinicius A.
# Bruno B.
# Paulo Cesar C.
# Rodolpho A.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------------
# Fabiano F.
# Ricardo P.
# José Pedro D.
# Nilson B.
# Lilian Christina O.
# Cristiano S.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Daniele Cristina O.
# Thiago Willian A.
# Jardel B.
# Márcia Cristina V.
# Vinícius C.
# Rodrigo F.
# Fabiano D.
# João C.
# Lorena M.
# Leonardo P.
# Marcela B.
# Raphael I.
# Norio M.
# Luisa L.
# Daniel C.
# Daniela B.
# Warla  L.
# José Eustáquio M.
# Andre O.
# Marcus Vinícius S.
# Alison Demori B.
# Landi A.
# Wesley S.
# Luciana M.
# Leandro M.
# Vivaldo R.
# Thais R.
# Rafael B.
# Luciene F.
# Leonildes P.
# Wellington J.
# Fernando V.
# Leo R.
# Matheus L.
# Arthur D.
# Marcelo T.
# Vagner A.
# Andreia V.
# Hellen C.
# Daniel B.
# Juliana F.
# Rondinele S.
# Fabio Sadol d.
# Jair Antonio C.
# Andrea Geralda Rosa R.
# Diego M.
# Rodrigo J.
# Rodrigo J.
# Katânia N.
# Alexandre J.
# Adauto A.
# Cleide S.
# Dyonatan Diogo Dias S.
# Érika S.
# Junior S.
# Maria Dantas d.
# Juliano P.
# Helbia d.
# Vítor B.
# MARCELO C.
# Rafaella F.
# wilker f.
# Otávio F.
# Igor T.
# Marcelo Gomides M.
# Marlem B.
# Thiago N.
# João Paulo M.
# Marcos M.
# Jerveson L.
# Samuel R.
# Pedro de Freitas S.
# Sarah A.
# Jhony M.
# João M.
# Fernando Henrique d.
# Rafael R.
# Levite D.
# Bruno A.
# Lorena C.
# Thiago H.
# Julian D.
# Michel Oliveira ,.
# Mariana M.
# Bruna F.
# Lucas V.
# Jonnathan R.
# Arthur Kenji I.
# Laureano F.
# Rafael M.
# Antônio Carlos D.
# Tulio R.
# LUCAS MARIANO P.
# Gabriel D.
# Jordi R.
# Bruno C.
# Vanessa R.
# Warlley Gonçalves d.
# Leticia Fernanda B.
# Arthur M.
# Silas M.
# Osvaldo A.
# Letícia M.
# Thays L.
# Rubens L.
# Augusto G.
# Renato  V.
#
# Descriptive Terms: Strategy, Chief, Officer
# ----------------------------------------------------------------------------------
# Guilherme P.
# Guilherme P.
#
# Descriptive Terms: Senior
# -----------------------------------------------------------------------------------------
# Bruno M.
# Fabio B.
# Fabiano F.
# Lucas R.
# Michel Oliveira ,.
# Wannisson F.
#
# Descriptive Terms: Junior
# --------------------------------------------------------
# Dyonatan Diogo Dias S.
# Bruna F.
#
# Descriptive Terms: Business
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcus Vinícius M.
# Marcus Vinícius M.
# Alinson C.
# Warla  L.
# Hugo A.
# Carlos Humberto N.
# Karina T.
# Otávio F.
# Samuel R.
# Rodrigo Moraes P.
# Thiago A.
# Ariel Leon L.
# Laureano F.
# Laureano F.
# Jessiane G.
# Letícia M.
#
# Descriptive Terms: de, Engenheiro
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Guilherme S.
# Rafael F.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Patrick Godinho O.
# Rafael R.
# Bruno C.
# Gilberto M.
# Everton A.
# Danniel F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Willian A.
# Paula B.
# Lucas T.
# Ricardo D.
# Rafael F.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Paulo A. S.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Igor T.
# Rafael A.
# José J.
# Henrique M.
# Hildeu N.
# Tiago S.
# Jacqueline M.
# Lucas César N.
# Vinícius R.
# João Augusto M.
#
# Descriptive Terms: Assistente
# ----------------------------------------------------------------------------------------------
# Murillo M.
# Amanda Beraldo  .
# Joyce M.
# Lurana G.
# Anderson B.
# Pâmella R.
# Nelson A.
# Gildean C.
# Clemar S.
#
# Descriptive Terms: Custo, Analista, e
# ----------------------------------------------------------------------------
#  Crênio Roberto S.
#  Crênio Roberto S.
#
# Descriptive Terms: Developer
# ----------------------------------------------------------------------------------------------------------
# Marcos L.
# Rita de Cássia C.
# Tulio d.
# Nilson B.
# Lucas L.
# Vinicius A.
# Bruno B.
# Paulo Cesar C.
# Rodolpho A.
#
# Descriptive Terms: Informática
# ----------------------------------------------------
# Efraim M.
# Gustavo P.
# Rodrigo B.
#
# Descriptive Terms: Representante
# --------------------------------------------------------------------------------
# Daniel C.
# Geojuris - K.
# Pedro C.
# Alex Sandro B.
#
# Descriptive Terms: Desenvolvimento
# -----------------------------------------------------------------------------------------
# Arthur D.
# Arthur D.
# Arthur M.
#
# Descriptive Terms: Analyst
# --------------------------------------------------------------------------------------------------------
# Natália F.
# Vinícius D.
# Stephanny A.
# Breno S.
# Carlos F.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------------------
# César B.
# Daniel C.
# Fabricio Ribeiro P.
# Fernanda R.
# Geojuris - K.
# Michele O.
# Douglas Alves C.
# Gildean C.
# Luciano Martins T.
#
# Descriptive Terms: Gerente
# ---------------------------------------------------------------------------------------------------------
# Grispe J.
# Bruno M.
# Alessandra d.
# Erasmo A.
# Viviane N.
# Fabíola B.
# Flávia M.
# Renato M.
# Henrique C.
# Gregonio E.
# Gabriel P.
# Antonio Cristiano D.
# Fellipe P.
# Kriscia M.
# Ranier B.
# Lilian S.
# Fidelidade V.
# Thiago Henrique M.
# Washington Luiz S.
# Gabriella d.
# Neto C.
# Maria Cecília A.
# Anderson L.
#
# Descriptive Terms: Outsourcing, e, ETL, relatório,
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Rodrigo J.
# Rodrigo J.
# Rodrigo J.
#
# Descriptive Terms: Comercial
# --------------------------------------------------------------------------------
# César B.
# Fabricio Ribeiro P.
# Fernanda R.
# Michele O.
# Douglas Alves C.
# Gildean C.
# Luciano Martins T.
#
# Descriptive Terms: Segurança, Trabalho, do
# ----------------------------------------------------------------
# Lariane d.
# Jane A.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------------------
# Fabio B.
# Thiago Willian A.
# Henrique C.
# Rafael B.
# Roberto S.
# Davi C.
# Ítalo N.
# Marcelo M.
# Nayara D.
# Francisco Danilo S.
# Vicente R.
# Osvaldo A.
#
# Descriptive Terms: Analista
# ----------------------------------------------------------------------------
# Daniele Cristina O.
# Jardel B.
# Márcia Cristina V.
# Rodrigo F.
# Fabiano D.
# João C.
# Lorena M.
# Leonardo P.
# Marcela B.
# Raphael I.
# Norio M.
# Daniel C.
# Daniela B.
# Warla  L.
# José Eustáquio M.
# Andre O.
# Alison Demori B.
# Landi A.
# Wesley S.
# Luciana M.
# Leandro M.
# Vivaldo R.
# Thais R.
# Rafael B.
# Luciene F.
# Leonildes P.
# Wellington J.
# Fernando V.
# Leo R.
# Matheus L.
# Arthur D.
# Marcelo T.
# Andreia V.
# Daniel B.
# Juliana F.
# Rondinele S.
# Fabio Sadol d.
# Jair Antonio C.
# Andrea Geralda Rosa R.
# Diego M.
# Rodrigo J.
# Rodrigo J.
# Katânia N.
# Alexandre J.
# Cleide S.
# Dyonatan Diogo Dias S.
# Junior S.
# Anselmo J.
# Maria Dantas d.
# Juliano P.
# Helbia d.
# Vítor B.
# MARCELO C.
# wilker f.
# Otávio F.
# Igor T.
# Marlem B.
# Thiago N.
# João Paulo M.
# Marcos M.
# Samuel R.
# Pedro de Freitas S.
# Sarah A.
# Jhony M.
# João M.
# Fernando Henrique d.
# Rafael R.
# Levite D.
# Bruno A.
# Lorena C.
# Thiago H.
# Julian D.
# Mariana M.
# Bruna F.
# Lucas V.
# Jonnathan R.
# Arthur Kenji I.
# Laureano F.
# Rafael M.
# Tulio R.
# LUCAS MARIANO P.
# Gabriel D.
# Jordi R.
# Bruno C.
# Vanessa R.
# Warlley Gonçalves d.
# Leticia Fernanda B.
# Arthur M.
# Silas M.
# Letícia M.
# Thays L.
# Rubens L.
# Augusto G.
# Renato  V.
#
# Descriptive Terms: de, Software, Engenheiro
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Guilherme S.
# Rafael F.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Patrick Godinho O.
# Rafael R.
# Bruno C.
# Gilberto M.
# Danniel F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Willian A.
# Paula B.
# Lucas T.
# Ricardo D.
# Rafael F.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Igor T.
# Rafael A.
# José J.
# Henrique M.
# Hildeu N.
# Tiago S.
# Lucas César N.
# Vinícius R.
#
# Descriptive Terms:
# ----------------------------------------------------------
# Marcus Vinícius M.
# Henrique C.
# Henrique C.
# Douglas L.
# Douglas L.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------------------------------------------------------------
# Guilherme S.
# Effrain Roney B.
# Nathan P.
# Larissa A.
# Leticia Fernanda B.
# Henrique M.
# Hildeu N.
# Jacqueline M.
#
# Descriptive Terms: software
# -------------------------------------------
# Rafael F.
# Vinícius C.
# Katânia N.
# Arthur Kenji I.
# Vinícius R.
#
# Descriptive Terms: Supervisor
# --------------------------------------------------------------
# Rafael R.
# Djone machado M.
# Rafael B.
# Aryel C.
# Lucas Emiliano d.
# Frederico V.
# Fabio P.
# Richard R.
# Tatiane M.
# Renata A.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------
# Daniela B.
# Landi A.
# Junior S.
# Gabriel D.
# Isadora R.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Alinson C.
# Laura S.
# Stephanny A.
# Hugo C.
# Anderson A.
# Matheus S.
# Rodrigo Moraes P.
# Gabriel Hernandez S.
# Jessiane G.
#
# Descriptive Terms: de, Software, Engenheiro
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Guilherme S.
# Rafael F.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Rafael R.
# Bruno C.
# Danniel F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Willian A.
# Paula B.
# Lucas T.
# Ricardo D.
# Rafael F.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Igor T.
# Rafael A.
# José J.
# Henrique M.
# Hildeu N.
# Tiago S.
# Lucas César N.
# Vinícius R.
#
# Descriptive Terms: System
# ------------------------------------------------
# Thiago Henrique C.
# Breno S.
#
# Descriptive Terms: Manutenção
# -----------------------------------------------------
# Bruno R.
# Thiago Henrique M.
#
# Descriptive Terms: Diretor
# ---------------------------------------------------------------------------------------------------
# Robson X.
# César B.
# Fabricio Ribeiro P.
# Carlos Á.
# Kátia L.
# Daniel R.
# Joao Ricardo V.
# Luiz Henrique B.
# Vicente N.
# Douglas Alves C.
# Dionata T.
# Luciano Martins T.
# Jair F.
# Pro D.
# Jonatas R.
#
# Descriptive Terms:
# ----------------------------------------------------------
# Rodrigo J.
# Rodrigo J.
# Junior S.
# Isadora R.
#
# Descriptive Terms: Chief, Officer
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Antônio C.
# Guilherme P.
# Humberto O.
# Edjay M.
# Diego D.
# Rafael M.
# Bruno O.
# Bruno O.
# Bruno O.
# Bruno O.
# Thales M.
# Gustavo S.
# Wanderson M.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Fabio B.
# Gabriel D.
# Thiago Willian A.
# Leandro S.
# Fábio Augusto F.
# Paulo Eustáquio C.
# Renato F.
# Rafael B.
# Roberto S.
# Luis J.
# Ítalo N.
# Conrado F.
# Luis H.
# Marcelo M.
# Nayara D.
# Francisco Danilo S.
# Flammarion C.
# Vicente R.
# Osvaldo A.
#
# Descriptive Terms: Pleno
# --------------------------------------------------------------------
# Landi A.
# Vítor B.
# João Paulo M.
# Gabriel D.
# Leticia Fernanda B.
#
# Descriptive Terms: DE, VENDAS
# ---------------------------------------------------------
# Leandro D.
# ROMES V.
#
# Descriptive Terms: Psicóloga
# ----------------------------------------------
# Viviane V.
# Larissa R.
# Suzanny M.
#
# Descriptive Terms: Developer
# --------------------------------------------------------------------------
# Marcos L.
# Rodrigo S.
# Rodrigo S.
# Vinicius A.
# Thiago F.
#
# Descriptive Terms: Analista, BI
# -----------------------------------------------------------------
# Emmanuel d.
# Osvaldo A.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------
# Grispe J.
# Bruno M.
# Alessandra d.
# Erasmo A.
# Fabíola B.
# Flávia M.
# Renato M.
# Henrique C.
# Gregonio E.
# Gabriel P.
# Antonio Cristiano D.
# Érika S.
# Fellipe P.
# Kriscia M.
# Ranier B.
# Lilian S.
# Thiago Henrique M.
# Washington Luiz S.
# Gabriella d.
# Neto C.
# Maria Cecília A.
# Anderson L.
#
# Descriptive Terms: Negócios
# ---------------------------------------------
# Jardel B.
# Igor T.
# Natasha H.
# Jair F.
#
# Descriptive Terms: Analista
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Daniele Cristina O.
# Marcos Antonio O.
# Thiago Willian A.
# Jardel B.
# Márcia Cristina V.
# Guilherme S.
# Rodrigo F.
# Fabiano D.
# João C.
# Lorena M.
# Willian B.
# Leonardo P.
# Mauricio D.
# Júnior, A.
# Marcela B.
# Raphael I.
# Norio M.
# Daniel C.
# Daniela B.
# Warla  L.
# José Eustáquio M.
# Andre O.
# Alison Demori B.
# Landi A.
# Wesley S.
# Luciana M.
# Alécio Fernando B.
# Leandro M.
# Vivaldo R.
# Thais R.
# Rafael B.
# Luciene F.
# Leonildes P.
# Wellington J.
# Fernando V.
# Leo R.
# Matheus L.
# Arthur D.
# Marcelo T.
# Vagner A.
# Andreia V.
# Hugo Humberto R.
# Jéssica D.
# Daniel B.
# Juliana F.
# Rondinele S.
# Fabio Sadol d.
# Jair Antonio C.
# Andrea Geralda Rosa R.
# Diego M.
# Rodrigo J.
# Rodrigo J.
# Katânia N.
# Alexandre J.
# Cleide S.
# Dyonatan Diogo Dias S.
# Érika S.
# Junior S.
# Maria Dantas d.
# Juliano P.
# Helbia d.
# Vítor B.
# MARCELO C.
# Rafaella F.
# wilker f.
# Otávio F.
# Igor T.
# Marlem B.
# Thiago N.
# Thiago P.
# João Paulo M.
# Marcos M.
# Jerveson L.
# Samuel R.
# Pedro de Freitas S.
# Sarah A.
# Jhony M.
# Alexandre F.
# Vitor Bruno L.
# João M.
# Fernando Henrique d.
# Rafael R.
# Levite D.
# Bruno A.
# Lorena C.
# Thiago H.
# Julian D.
# Mariana M.
# Thiago A.
# Bruna F.
# Lucas V.
# Jonnathan R.
# Jonnathan R.
# Arthur Kenji I.
# Laureano F.
# Rafael M.
# Antônio Carlos D.
# Tulio R.
# Kayke M.
# LUCAS MARIANO P.
# Gabriel D.
# Jordi R.
# Bruno C.
# Vanessa R.
# Warlley Gonçalves d.
# Leticia Fernanda B.
# Daniella S.
# Arthur M.
# Silas M.
# Osvaldo A.
# Letícia M.
# Thays L.
# Rubens L.
# Augusto G.
# Renato  V.
#
# Descriptive Terms: Especialista
# --------------------------------------------------------------------------------------------------------------------------------------------
# Rodrigo M.
# Rodrigo C.
# Luzidalva L.
# Elisangela F.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Fabio B.
# Thiago Willian A.
# Thiago Willian A.
# Rafael B.
# Marcelo T.
# Vagner A.
# Ítalo N.
# Érika S.
# Rafaella F.
# Nayara D.
# Otávio F.
# Jerveson L.
# Antônio Carlos D.
# Vicente R.
# Osvaldo A.
#
# Descriptive Terms: System, Analyst
# ------------------------------------------------------------
# Guilermo P.
# Breno S.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------
# César B.
# Fabricio Ribeiro P.
# Murillo M.
# Joyce M.
# Alexandre A.
# Douglas Alves C.
# Lurana G.
# Anderson B.
# Pâmella R.
# Nelson A.
# Gildean C.
# Luciano Martins T.
# Clemar S.
#
# Descriptive Terms: Consultor
# --------------------------------------------------------------------------------------------------------------
# Gabriel D.
# Leandro S.
# Fábio Augusto F.
# Paulo Eustáquio C.
# Renato F.
# Luis J.
# Conrado F.
# Luis H.
# Flammarion C.
#
# Descriptive Terms: Técnico
# ---------------------------------------------------------------------------------------------------------
# Gesmar d.
# Efraim M.
# Bruno W.
# Jonathan C.
# Edson Nere A.
# João Alair C.
# Sergio dos Santos M.
# salatiel n.
# Andrei Visentini F.
# Alan Nicolas d.
#
# Descriptive Terms: Researcher
# -------------------------------------------------------------
# Cláudio Henrique M.
# Isabella F.
#
# Descriptive Terms: Gerente
# --------------------------------------------------------------
# Grispe J.
# Bruno M.
# Alessandra d.
# Erasmo A.
# Fabíola B.
# Flávia M.
# Renato M.
# Henrique C.
# Gregonio E.
# Gabriel P.
# Antonio Cristiano D.
# Fellipe P.
# Kriscia M.
# Ranier B.
# Lilian S.
# Thiago Henrique M.
# Washington Luiz S.
# Gabriella d.
# Neto C.
# Anderson L.
#
# Descriptive Terms: Técnico
# ...
# Marcelo G.
# Rafael Guilherme F.
#
# Descriptive Terms: Proprietário
# ----------------------------------------------------
# Thiago Vinicius S.
# Paulo Henrique T.
# Dionata T.
# Vinícius B.
# JEAN T.
# Arilson J.
# Marcelo B.
# RENATO C.
# Soma H.
#
# Descriptive Terms: em, Técnico
# -------------------------------------------------------------------------
# Gesmar d.
# Bruno W.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------------------------------
# Fabiano F.
# Marcos L.
# Danilo H.
# Rita de Cássia C.
# Herivelton M.
# Nilson B.
# Lucas L.
# Vinicius A.
# Paulo Cesar C.
# Rodolpho A.
#
# Descriptive Terms: Developer
# -------------------------------------------------------------------------------------------------------------
# Marcos L.
# Rodrigo S.
# Joel S.
# Vinicius A.
# Paulo Cesar C.
# Rodolpho A.
#
# Descriptive Terms: vendas
# -----------------------------------------
# Miranda R.
# Flammarion C.
# Alex Sandro B.
# FELIX J.
# Maria aparecida A.
# Anderson L.
#
# Descriptive Terms: Of, Operations
# ------------------------------------------------------------------
# Rodrigo S.
# JEANDERNEY F.
#
# Descriptive Terms: Analista
# ------------------------------------------------------------------------------------------------------------------------------------
# Thiago Willian A.
# Marcelo T.
# Vagner A.
# Érika S.
# Rafaella F.
# Otávio F.
# Jerveson L.
# Antônio Carlos D.
#
# Descriptive Terms: IT
# --------------------------------------------
# Lafaete R.
# Ary R.
#
# Descriptive Terms: de, Engenheiro
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Guilherme S.
# Rafael F.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Rafael R.
# Bruno C.
# Danniel F.
# Danniel F.
# Larissa A.
# Paulo Henrique M.
# Willian A.
# Lucas T.
# Ricardo D.
# Rafael F.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Paulo A. S.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Igor T.
# Rafael A.
# José J.
# Henrique M.
# Hildeu N.
# Tiago S.
# Jacqueline M.
# Vinícius R.
#
# Descriptive Terms: Business
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcus Vinícius M.
# Marcus Vinícius M.
# Hugo A.
# Stephanny A.
# Carlos Humberto N.
# Vanessa M.
# Otávio F.
# Samuel R.
# Thiago A.
# Ariel Leon L.
# Laureano F.
# Laureano F.
# Jessiane G.
# Letícia M.
#
# Descriptive Terms: Sistemas
# -----------------------------------------------
# Vítor B.
# Silas M.
#
# Descriptive Terms: Diretor
# --------------------------------------------------------------------------------------------------------------------------------
# Robson X.
# César B.
# Fabricio Ribeiro P.
# Carlos Á.
# Daniel R.
# Joao Ricardo V.
# Luiz Henrique B.
# Vicente N.
# Douglas Alves C.
# Dionata T.
# Luciano Martins T.
# Consultor e Auditor F.
# Jair F.
# Pro D.
# Jonatas R.
#
# Descriptive Terms: Diretor
# -------------------------------------------------------------
# César B.
# Fabricio Ribeiro P.
# Carlos Á.
# Daniel R.
# Joao Ricardo V.
# Luiz Henrique B.
# Vicente N.
# Douglas Alves C.
# Dionata T.
# Luciano Martins T.
# Jair F.
# Pro D.
# Jonatas R.
#
# Descriptive Terms: Analytics
# ---------------------------------------------
# Henrique C.
# Henrique C.
# Joeudes A.
#
# Descriptive Terms: Analista, de
# -----------------------------------------------------------------------------------------------------------------------------------------
# Marcos Antonio O.
# Victor A.
# Guilherme S.
# Willian B.
# Mauricio D.
# Arthur D.
# Hugo Humberto R.
# Jéssica D.
# Thiago P.
# Alexandre F.
# Vitor Bruno L.
# Thiago A.
# Jonnathan R.
# Laureano F.
# Kayke M.
#
# Descriptive Terms: Scrum
# --------------------------------------------
# Bruno M.
# Lucas C.
# Josenildo J.
# Raul A.
#
# Descriptive Terms: Consultoria
# --------------------------------------------------
# Naize D.
# Vanessa M.
#
# Descriptive Terms: Business
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcus Vinícius M.
# Marcus Vinícius M.
# Thiago A.
# Hugo A.
# Stephanny A.
# Carlos Humberto N.
# Vanessa M.
# Hugo C.
# Jessiane G.
#
# Descriptive Terms: Director
# --------------------------------------------------
# Fernando M.
# Thiago A.
#
# Descriptive Terms: Analyst
# -------------------------------------------------------------------
# Natália F.
# Stephanny A.
# Breno S.
#
# Descriptive Terms: Consultor
# -------------------------------------------------------
# Gabriel D.
# Conrado F.
# Luis H.
# Rodrigo M.
# Flammarion C.
#
# Descriptive Terms: Analista
# --------------------------------------------------------------------------------------------------------------
# Thiago Willian A.
# Vagner A.
# Érika S.
# Rafaella F.
# Jerveson L.
# Antônio Carlos D.
#
# Descriptive Terms: Senior, Analyst
# -------------------------------------------------------------------------------
# Weder C.
# Hugo C.
#
# Descriptive Terms: Analista, de
# -------------------------------------------------------------------------------------------------------
# Marcos Antonio O.
# Victor A.
# Guilherme S.
# Willian B.
# Mauricio D.
# Hugo Humberto R.
# Jéssica D.
# Thiago P.
# Alexandre F.
# Vitor Bruno L.
# Thiago A.
# Jonnathan R.
# Laureano F.
# Kayke M.
#
# Descriptive Terms: Pleno
# -----------------------------------------------------
# Landi A.
# Vítor B.
# Gabriel D.
# Leticia Fernanda B.
#
# Descriptive Terms: Director, Of
# ----------------------------------------------------------------------------
# Rodrigo S.
# Flávio P.
#
# Descriptive Terms: Negócios
# -------------------------------------------------
# Gabriel D.
# Jardel B.
# Igor T.
# Jair F.
#
# Descriptive Terms: Designer
# -------------------------------------------------
# Olívio F.
# Fabricio M.
#
# Descriptive Terms: BI
# ----------------------------------------------
# Fabio B.
# Thiago Willian A.
# Rafael B.
# Ítalo N.
# Nayara D.
#
# Descriptive Terms: Analista, financeiro
# -----------------------------------------------------------------
# Alécio Fernando B.
# Vagner A.
# Jerveson L.
#
# Descriptive Terms: Lea
# ------------------------------------------------------------
# Fabiano F.
# José Pedro D.
# Nilson B.
# Lilian Christina O.
#
# Descriptive Terms: Partner
# ------------------------------------------------------
# Carlos B.
# Wellington M.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------
# Bruno M.
# Fabio B.
# Fabiano F.
# Lucas R.
# Danilo H.
# Herivelton M.
# Wannisson F.
#
# Descriptive Terms: Intelligence, Business
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcus Vinícius M.
# Marcus Vinícius M.
# Hugo A.
# Carlos Humberto N.
# Laureano F.
#
# Descriptive Terms:
# -----------------------------------------------------------
# Herivelton M.
# Djone machado M.
# Silvio Carlos d.
# Rafael B.
# Márcio A.
# Aryel C.
# Lucas Emiliano d.
# Frederico V.
# Fabio P.
# Richard R.
# Tatiane M.
# Renata A.
#
# Descriptive Terms: Intelligence, Business
# -----------------------------------------------------------------------------------------------------------------------
# Hugo A.
# Carlos Humberto N.
# Laureano F.
#
# Descriptive Terms: r
# --------------------------------------
# Danilo H.
# Herivelton M.
#
# Descriptive Terms: de, Engenheiro
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Guilherme S.
# Rafael F.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Rafael R.
# Bruno C.
# Danniel F.
# Danniel F.
# Larissa A.
# Paulo Henrique M.
# Willian A.
# Lucas T.
# Ricardo D.
# Rafael F.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Paulo A. S.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Rafael A.
# José J.
# Henrique M.
# Hildeu N.
# Tiago S.
# Jacqueline M.
# Vinícius R.
#
# Descriptive Terms: ETL, relatório,, Outsourcing, Projetista, de, e
# ---------------------------------------------------------------------------------------------------------------------------------------
# Rodrigo J.
# Rodrigo J.
#
# Descriptive Terms: Gerente
# -----------------------------------------
# Grispe J.
# Bruno M.
# Alessandra d.
# Erasmo A.
# Fabíola B.
# Flávia M.
# Renato M.
# Henrique C.
# Gregonio E.
# Gabriel P.
# Fellipe P.
# Kriscia M.
# Ranier B.
# Lilian S.
# Thiago Henrique M.
# Washington Luiz S.
# Gabriella d.
# Neto C.
# Anderson L.
#
# Descriptive Terms: Director
# -------------------------------------------------------------
# Fernando M.
# Walber L.
#
# Descriptive Terms: Chief, Officer
# ----------------------------------------------------------------------------------------------------
# Guilherme P.
# Humberto O.
# Edjay M.
# Rafael M.
# WG  L.
# Thales M.
# Wanderson M.
#
# Descriptive Terms: de, Software, Engenheiro
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Rafael F.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Rafael R.
# Bruno C.
# Danniel F.
# Danniel F.
# Paulo Henrique M.
# Willian A.
# Lucas T.
# Ricardo D.
# Rafael F.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Rafael A.
# José J.
# Tiago S.
# Vinícius R.
#
# Descriptive Terms: Data
# --------------------------------
# Marcus Vinícius M.
# Henrique C.
# Henrique C.
# Douglas L.
#
# Descriptive Terms: Analista
# -------------------------------------------------------------------------------------------
# Thiago Willian A.
# Vagner A.
# Érika S.
# Rafaella F.
# Jerveson L.
#
# Descriptive Terms: Chief, Officer
# -------------------------------------------------------------------------------------------------
# Antônio C.
# Guilherme P.
# Humberto O.
# Edjay M.
# Rafael M.
# Thales M.
# Wanderson M.
#
# Descriptive Terms: Agile
# ---------------------------------------------
# Bruno M.
# Jennifer d.
#
# Descriptive Terms: Analyst, IT
# -----------------------------------------------------------
# Laura S.
# Anderson A.
#
# Descriptive Terms: Chief, Officer
# ------------------------------------------------------------------------
# Antônio C.
# Guilherme P.
#
# Descriptive Terms: Developer
# ----------------------------------------------------
# Paulo Cesar C.
# Rodolpho A.
#
# Descriptive Terms: Pleno
# ---------------------------------------
# Vítor B.
# Leticia Fernanda B.
#
# Descriptive Terms: Diretor
# ----------------------------------------------------
# César B.
# Fabricio Ribeiro P.
# Luiz Henrique B.
# Douglas Alves C.
# Luciano Martins T.
#
# Descriptive Terms: Senior
# -----------------------------------------------------------------------------------------
# Bruno M.
# Fabio B.
# Lucas R.
# Marcelo G.
# Wannisson F.
#
# Descriptive Terms: Advogada
# -------------------------------------------
# Lilian Divina L.
# Isadora R.
#
# Descriptive Terms: Consultant
# ----------------------------------------------------------------
# Ítalo N.
# Vanessa M.
# Khalid Abdullah A.
#
# Descriptive Terms: Faturamento
# ---------------------------------------------------
# Fabio Sadol d.
# Helbia d.
#
# Descriptive Terms: Quality, Analyst
# ------------------------------------------------------------
# Sara Áquila M.
# Natália F.
#
# Descriptive Terms: Consultor
# --------------------------------------------------------------------
# Gabriel D.
# Fábio Augusto F.
# Paulo Eustáquio C.
# Luis J.
# Conrado F.
# Luis H.
# Flammarion C.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------
# Natália F.
# Stephanny A.
# Vanessa M.
# Hugo C.
#
# Descriptive Terms: de, Engenheiro
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Rafael F.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Rafael R.
# Bruno C.
# Danniel F.
# Danniel F.
# Willian A.
# Lucas T.
# Ricardo D.
# Rafael F.
# Rogério G.
# Michel R.
# Leonardo M.
# Gustavo F.
# Paulo A. S.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Rafael A.
# José J.
# Tiago S.
# Jacqueline M.
# Vinícius R.
#
# Descriptive Terms: Suporte
# -------------------------------------------------
# Maria Dantas d.
# Lurana G.
#
# Descriptive Terms: Designer
# --------------------------------------------
# Olívio F.
# Ludymilla C.
#
# Descriptive Terms: Suporte
# ---------------------------------------------
# Maria Dantas d.
# Pedro C.
#
# Descriptive Terms: Consultor
# --------------------------------------------------------------------------------------------------------
# Gabriel D.
# Fábio Augusto F.
# Paulo Eustáquio C.
# Carlos Humberto N.
# Rodrigo Furtado A.
# Conrado F.
# Luis H.
# Flammarion C.
#
# Descriptive Terms: Consultant
# ----------------------------------------------------
# Ítalo N.
# Vanessa M.
#
# Descriptive Terms: Analista
# ------------------------------------------------------------------
# Thiago Willian A.
# Vagner A.
# Rafaella F.
# Jerveson L.
#
# Descriptive Terms: de, Engenheiro
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno B.
# Rafael F.
# Alcides Maurício G.
# João F.
# Leonardo Batista d.
# Arthur C.
# Erik U.
# Rafael R.
# Bruno C.
# Danniel F.
# Danniel F.
# Willian A.
# Lucas T.
# Ricardo D.
# Rafael F.
# Michel R.
# Leonardo M.
# Gustavo F.
# Paulo A. S.
# Pedro C.
# Rodrigo U.
# Rodrigo U.
# Ricardo D.
# Rafael A.
# José J.
# Tiago S.
# Jacqueline M.
# Vinícius R.
#
# Descriptive Terms: Consultor, sênior
# ------------------------------------------------------------
# Fábio Augusto F.
# Paulo Eustáquio C.
# Rodrigo Furtado A.
#
# Descriptive Terms: processos
# ------------------------------------------------
# Amilker C.
# LUCAS MARIANO P.
# Vanessa R.
#
# Descriptive Terms: Senior
# -------------------------------------------
# Bruno M.
# Fabio B.
#
# Descriptive Terms: Técnico
# --------------------------------------------
# Danilo H.
# Luiz Henrique B.
#
# Descriptive Terms: Lea
# -------------------------------------------
# Fabiano F.
# Nilson B.
# Lilian Christina O.
#
# Descriptive Terms: Billing, Telecom
# ------------------------------------------------------------------------
# Divya D.
# Bharath U.
#
# Descriptive Terms: de, Engenheiro
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Danniel F.
# Lucas T.
# Paulo A. S.
# Rodrigo U.
# Rafael A.
# Jacqueline M.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------------------------------------
# Victor A.
# Carlos Humberto N.
# Laureano F.
#
# Descriptive Terms: Assistant, Center
# --------------------------------------------------------
# Fabiano F.
# Cristiano S.
#
# Descriptive Terms: Analista
# ---------------------------------------------
# Thiago Willian A.
# Rafaella F.
#
# Descriptive Terms: Director
# --------------------------------------------------
# Fernando M.
# Rodrigo S.
#
# Descriptive Terms: de, Engenheiro
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Danniel F.
# Lucas T.
# Paulo A. S.
# Rodrigo U.
# Jacqueline M.
#
# Descriptive Terms: de, Engenheiro
# -----------------------------------------------------------------------------------------------------------------------------------------
# Lucas T.
# Paulo A. S.
# Jacqueline M.
#
# Descriptive Terms: Administrador
# ------------------------------------------------------------
# Eduardo S.
# Amanda V.
# Victor A.
# Pedro M.
# Rodrigo W.
#
# Descriptive Terms: BI
# ------------------------------------------
# Fabio B.
# Ítalo N.

# %% [markdown]
# ### Linkedin - Visualizando o agrupamento dos meus contatos por cargo

# %%
import os
import sys
import json
import webbrowser


class ComplexEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, complex):
             return [obj.real, obj.imag]
         # Let the base class default method raise the TypeError
        return json.JSONEncoder.default(self, obj)

HTML_TEMPLATE = 'dojo-tree.html'

data = {"label": "name", "temp_items": {}, "items": []}

clustered_contacts = cluster_contacts_by_title(CSV_FILE)

for titles in clustered_contacts:
    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    descriptive_terms = ', '.join(descriptive_terms)

    if descriptive_terms in data['temp_items']:
        data['temp_items'][descriptive_terms].extend([{'name': cc} for cc
                                                      in clustered_contacts[titles]])
    else:
        data['temp_items'][descriptive_terms] = [{'name': cc} for cc
                                                 in clustered_contacts[titles]]

for descriptive_terms in data['temp_items']:
    data['items'].append({"name": "%s (%s)" % (descriptive_terms,
                                               len(data['temp_items'][descriptive_terms]),),
                          "children": [i for i in
                                       data['temp_items'][descriptive_terms]]})

del data['temp_items']

# Open the template and substitute the data

if not os.path.isdir('out'):
    os.mkdir('out')

OUT = os.path.join('out', 'dojo-tree.html')

t = open(HTML_TEMPLATE).read()
f = open(OUT, 'w')
f.write(t % json.dumps(data, indent=4, cls=ComplexEncoder))


f.close()

webbrowser.open("file://" + os.path.join(os.getcwd(), OUT))
# Out:
# True
